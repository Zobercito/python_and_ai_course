# %% [markdown]
# #  Introducción Matplotlib and Pyplot
# <h6>8/31/22

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Forma mas simple de Plotear

# %%
#Plotear variables de una dimension
#Eje Y (ITERABLE)
#Eje X (INDEX)
plt.plot([0,1,4,9,16])

# %%
#Plotear variables de los dimensiones
x= np.linspace(0,10,20)
y=x**2
plt.plot(x,y)

# %%
#Plotear variables de los dimensiones
x= np.linspace(0,10,20)
y=x**2
plt.plot(x,y,'bo-')

# %%
import numpy as np
a = np.zeros((3, 3))
print(a)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]
#  [0. 0. 0.]]
